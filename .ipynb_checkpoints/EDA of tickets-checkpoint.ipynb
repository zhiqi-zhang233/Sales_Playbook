# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# ls
! ls
# Out:
# README.md                       midterm_data_processing.ipynb
# data                            sales-pipeline-processing.ipynb
# mappings.json

# %%
tickets = pd.read_csv('data/anonymized_hubspot_tickets.csv')
deals = pd.read_csv('data/anonymized_hubspot_deals.csv')
companies = pd.read_csv('data/anonymized_hubspot_companies.csv')
# Out:
# /var/folders/tp/mjpk8bl91n9f40bxrmwzxn140000gn/T/ipykernel_99072/837209339.py:3: DtypeWarning: Columns (24,25,28,32,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   companies = pd.read_csv('data/anonymized_hubspot_companies.csv')

# %%
len(deals)
# Out:
# 593

# %%
len(companies)
# Out:
# 19851

# %%
len(tickets)
# Out:
# 79

# %%
pd.set_option('display.max_columns', None)
tickets.head(n = 10)
# Out:
#         Create date  Ticket Tags Stage Date - Project Launch  \
# 0  2023-12-18 15:02          NaN                         NaN
# 1  2024-10-30 12:31          NaN                         NaN
# 2  2024-12-12 09:01          NaN                  2025-01-10
# 3  2023-09-07 16:37          NaN                         NaN
# 4  2025-02-14 13:34          NaN                         NaN
# 5  2024-07-31 10:27          NaN                  2024-10-04
# 6  2024-07-31 10:28          NaN                  2024-10-15
# 7  2024-09-10 09:29          NaN                         NaN
# 8  2023-08-28 15:52          NaN                         NaN
# 9  2023-12-05 13:02          NaN                  2023-12-18
#
#   Associated Contact  Category Target Launch Date Kickoff Call  \
# 0   Contact_b6d930b5       NaN                NaN   2023-12-27
# 1   Contact_aa84b2e1       NaN                NaN          NaN
# 2   Contact_fec7b624       NaN                NaN   2024-12-10
# 3   Contact_11c92d4d       NaN         2023-10-02   2023-06-08
# 4   Contact_78b60b6b       NaN                NaN          NaN
# 5   Contact_a4562b7d       NaN                NaN   2024-08-13
# 6   Contact_a4562b7d       NaN                NaN   2024-08-27
# 7   Contact_373c4ce1       NaN                NaN   2024-10-08
# 8   Contact_5c873e37       NaN         2023-09-22   2023-08-01
# 9   Contact_c212e2e2       NaN         2023-12-11   2023-12-06
#
#          Close date              Pipeline Stage Date - Project Initiation  \
# 0  2024-01-29 11:50  Project Success Plan                      2023-12-18
# 1  2025-02-10 11:18  Project Success Plan                             NaN
# 2               NaN  Project Success Plan                      2024-12-13
# 3  2024-01-04 13:28  Project Success Plan                             NaN
# 4               NaN  Project Success Plan                      2025-02-14
# 5  2024-12-20 11:12  Project Success Plan                      2024-07-31
# 6  2024-12-20 11:12  Project Success Plan                      2024-07-31
# 7  2024-12-20 11:12  Project Success Plan                      2024-09-10
# 8  2024-01-04 13:30  Project Success Plan                             NaN
# 9  2024-02-07 11:58  Project Success Plan                      2023-12-05
#
#    Stage Date - Planning Phase   Ticket status Stage Date - Execution  \
# 0                          NaN   Converted-Won             2024-01-02
# 1                          NaN            Lost                    NaN
# 2                          NaN  Project Launch             2025-01-03
# 3                          NaN   Converted-Won                    NaN
# 4                          NaN  Planning Phase                    NaN
# 5                          NaN            Lost             2024-09-13
# 6                          NaN            Lost             2024-09-20
# 7                          NaN   Converted-Won             2024-10-11
# 8                          NaN            Lost                    NaN
# 9                          NaN   Converted-Won             2023-12-05
#
#   Time to first agent email reply (HH:mm:ss)  Last CES survey rating Priority  \
# 0                                        NaN                     NaN      NaN
# 1                                   49:24:00                     NaN      NaN
# 2                                 1516:30:41                     NaN      NaN
# 3                                   26:25:51                     NaN      NaN
# 4                                   13:32:11                     NaN      NaN
# 5                                   00:06:00                     NaN      NaN
# 6                                   00:04:59                     NaN      NaN
# 7                                  156:06:35                     NaN      NaN
# 8                                   17:50:57                     NaN      NaN
# 9                                   73:04:42                     NaN      NaN
#
#   Associated Company Who will be creating the Syms?  \
# 0   Company_67d87cec                            NaN
# 1   Company_7588d0d5                            NaN
# 2   Company_90e34cd3                            NaN
# 3   Company_5c625991                            NaN
# 4   Company_d828370b                            NaN
# 5   Company_d29e78a9                            NaN
# 6   Company_d29e78a9                            NaN
# 7   Company_d29e78a9                            NaN
# 8   Company_133e939d                            NaN
# 9   Company_fdc87b32                            NaN
#
#   Stage Date - Closure Phase  Stage Date - Monitoring and Control Phase  \
# 0                 2024-01-29                                        NaN
# 1                        NaN                                        NaN
# 2                        NaN                                        NaN
# 3                        NaN                                        NaN
# 4                        NaN                                        NaN
# 5                 2024-12-20                                        NaN
# 6                 2024-12-20                                        NaN
# 7                 2024-12-20                                        NaN
# 8                        NaN                                        NaN
# 9                        NaN                                        NaN
#
#   Associated Company (Primary) Response time (HH:mm:ss)    Ticket ID  \
# 0             Company_67d87cec                      NaN   2193923207
# 1             Company_67d87cec                 49:24:00  15899166073
# 2             Company_d9482f6a               1516:30:41  17452741013
# 3             Company_5c625991                 26:25:51   1891106581
# 4             Company_d828370b                 13:32:11  20395039397
# 5             Company_d29e78a9                 00:06:00   3049197180
# 6             Company_d29e78a9                 00:04:59   3049195860
# 7             Company_d29e78a9                156:06:35   3295514681
# 8             Company_133e939d                 17:50:57   1891162968
# 9             Company_fdc87b32                 73:04:42   2143836064
#
#   Time to close (HH:mm:ss) Associated Deal Library index approved  \
# 0               1004:48:10   Deal_67d87cec                     No
# 1               2471:47:33             NaN                    NaN
# 2                      NaN   Deal_2fddb8b0                    Yes
# 3               2853:51:33             NaN                    NaN
# 4                      NaN   Deal_3c2a794a                    NaN
# 5               3409:45:22   Deal_6f0d61c8                    Yes
# 6               3409:44:15   Deal_6f0d61c8                    Yes
# 7               2426:42:24   Deal_6f0d61c8                    Yes
# 8               3094:37:43             NaN                    NaN
# 9               1534:55:58             NaN                    Yes
#
#   Training: General Overview        Latest Milestone  \
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                 2024-12-23                     NaN
# 3                 2023-07-12            Kickoff Call
# 4                        NaN                     NaN
# 5                 2024-09-23                     NaN
# 6                 2024-09-24                     NaN
# 7                        NaN                     NaN
# 8                        NaN            Kickoff Call
# 9                        NaN  Library Index Approved
#
#   Training: Deployment/User Management Training Requirements for the Trial  \
# 0                                           NaN                   Coaching
# 1                                           NaN                        NaN
# 2                                    2024-12-23       Assessment; Coaching
# 3                                    2023-07-19                 Onboarding
# 4                                           NaN                        NaN
# 5                                    2024-09-23                 Onboarding
# 6                                    2024-10-07                 Onboarding
# 7                                           NaN                 Onboarding
# 8                                           NaN                   Coaching
# 9                                           NaN                   Coaching
#
#   Training: Sym Building 101 Last modified date Type Trial End Date  \
# 0                        NaN   2025-02-14 13:39  NaN            NaN
# 1                        NaN   2025-02-14 13:39  NaN     2024-11-07
# 2                 2024-12-23   2025-02-14 13:39  NaN     2025-04-30
# 3                 2023-07-11   2025-02-14 13:39  NaN            NaN
# 4                        NaN   2025-02-17 23:38  NaN            NaN
# 5                 2024-09-23   2025-02-14 13:39  NaN     2024-10-02
# 6                 2024-10-01   2025-02-14 13:39  NaN     2024-10-02
# 7                        NaN   2025-02-14 13:39  NaN     2024-09-30
# 8                        NaN   2025-02-14 13:39  NaN            NaN
# 9                        NaN   2025-02-14 13:39  NaN            NaN
#
#   Training: Sym Building 201 Stage Date - Converted Won  \
# 0                        NaN                 2024-02-06
# 1                        NaN                        NaN
# 2                 2024-12-23                        NaN
# 3                 2023-08-01                 2024-01-04
# 4                        NaN                        NaN
# 5                 2024-09-23                        NaN
# 6                 2024-10-01                        NaN
# 7                        NaN                 2025-01-14
# 8                        NaN                        NaN
# 9                        NaN                 2024-02-07
#
#   Latest Milestone Update Date      Ticket name  \
# 0                          NaN  Ticket_4baf7886
# 1                          NaN  Ticket_88dda9e1
# 2                          NaN  Ticket_2226dda1
# 3                   2023-11-24  Ticket_6c996e04
# 4                          NaN  Ticket_14c6e9a9
# 5                          NaN  Ticket_c2ae38e4
# 6                          NaN  Ticket_5f8a9f64
# 7                          NaN  Ticket_401c0394
# 8                   2023-11-24  Ticket_5fd136b4
# 9                   2023-12-05  Ticket_fdc87b32
#
#                                       Trial Overview Trial Start Date  \
# 0                                                NaN              NaN
# 1                                                NaN       2024-11-05
# 2                           Trial until end of April       2024-12-11
# 3  Coaching already implemented, adding onboardin...              NaN
# 4                                                NaN              NaN
# 5                                        Xfinity POC       2024-08-02
# 6                               Transcom POC for UPS       2024-08-02
# 7                                 Coach for training       2024-08-01
# 8  Giving Tandem a free trial of coaching through...              NaN
# 9             coaching use case for their sales team              NaN
#
#   1st Syms presented for review Project Launch Day Training: Reporting  \
# 0                           NaN                NaN                 NaN
# 1                           NaN                NaN                 NaN
# 2                    2024-12-23         2025-01-06          2024-12-23
# 3                           NaN         2023-06-14          2023-07-19
# 4                           NaN                NaN                 NaN
# 5                    2024-09-23         2024-09-30          2024-09-23
# 6                    2024-09-27         2024-10-10          2024-10-01
# 7                           NaN                NaN                 NaN
# 8                           NaN                NaN                 NaN
# 9                           NaN                NaN                 NaN
#
#   Construction of 1st Sym begun Trial Required  Was the sym QAed?
# 0                    2023-12-27            NaN                NaN
# 1                           NaN            NaN                NaN
# 2                    2024-12-11            NaN                NaN
# 3                           NaN            NaN                NaN
# 4                           NaN            NaN                NaN
# 5                    2024-09-27            NaN                NaN
# 6                    2024-09-16            NaN                NaN
# 7                    2024-10-10            NaN                NaN
# 8                           NaN            NaN                NaN
# 9                    2023-12-01            NaN                NaN

# %%
### remove columns with more than 90% missing values
tickets_col_remove = tickets.loc[:, tickets.isnull().mean() > 0.9].columns
tickets = tickets.loc[:, tickets.isnull().mean() < 0.9]

# %% [markdown]
# ### To connect tickets data with other datasets:
# - Associated Company (Primary) --> links to companies dataset (doesn't work very well)
# - Associated Deal --> links to deals dataset
# - Ticket ID --> links to companies dataset via CompanyToTickets mapping

# %%
# tickets['Associated Company (Primary)']

# %%
pd.set_option('display.max_columns', None)
companies.head(n = 2)
# Out:
#   Parent Company CCaaS  Annual Revenue Target Account Associated Contact  \
# 0            NaN   NaN    1.000000e+09            NaN   Contact_ef780380
# 1            NaN   NaN             NaN            NaN   Contact_93373ba5
#
#    Number of Form Submissions  Total Agents Web Technologies Close Date  \
# 0                         0.0           NaN         Route 53        NaN
# 1                         NaN           NaN              NaN        NaN
#
#    # of Agents Total  Number of times contacted Contact with Primary Company  \
# 0                NaN                        5.0             Company_ef780380
# 1                NaN                        NaN                          NaN
#
#   ICP Fit Level  Revenue range  # of Agents Contracted    Record ID  \
# 0           NaN            NaN                     NaN  25246439235
# 1           NaN            NaN                     NaN  22987081774
#
#           Time Zone Primary Industry  Number of Pageviews  Primary Company  \
# 0  America/New_York              NaN                  0.0              NaN
# 1               NaN              NaN                  NaN              NaN
#
#    Year Founded  ICP  Industry group Segmentation LMS System  \
# 0           NaN  NaN             NaN          NaN        NaN
# 1           NaN  NaN             NaN          NaN        NaN
#
#   SymTrain Use Cases Associated Company  BPO SSO Application State/Region  \
# 0                NaN                NaN  NaN             NaN           OH
# 1                NaN                NaN  NaN             NaN          NaN
#
#    SymTrain Product Contract End Date SSO Implemented? Consolidated Industry  \
# 0               NaN               NaN              NaN            (No value)
# 1               NaN               NaN              NaN            (No value)
#
#   Type  Number of Employees BPO Program Primary Sub-Industry  \
# 0  NaN               5000.0         NaN                  NaN
# 1  NaN                  NaN         NaN                  NaN
#
#    Number of Sessions  WFM Country/Region                  Industry  \
# 0                 0.0  NaN  United States  HVAC and plumbing supply
# 1                 NaN  NaN            NaN              Pest Control
#
#         Create Date      Company name Last Modified Date BPO Program Tier
# 0  2024-10-30 10:51  Company_4fc73a2a   2025-02-14 13:39              NaN
# 1  2024-09-12 18:30  Company_f3f7e884   2025-02-14 13:39              NaN

# %% [markdown]
# # Merge the tickets dataframe and the companies dataset
# ### Approach 1: Use the Associated Company (Primary) from tickets and Company name from companies to merge the 2 dataframes, only 48 overlaps

# %%
### only 48 out of 79 overlaps between company ids from ticket and company dataset
len(set(tickets['Associated Company (Primary)']).intersection(companies['Company name']))
# Out:
# 48

# %% [markdown]
# ### Approach 2: Use the mappings from the mappings.json file

# %%
### read in the mapping file
import json

with open('mappings.json', 'r') as f:
    mappings = json.load(f)

# %%
mappings.keys()
# Out:
# dict_keys(['CompanyToDeals', 'CompanyToTickets', 'ParentChildRelationships', 'TicketToDeal'])

# %% [markdown]
# - `CompanyToDeals`: contains the mappings from company ID to Deals ID
# - `CompanyToTickets`: contains the mappings from company ID to Tickets ID
# - `TicketToDeal`: contains the mappings from Ticket ID to Deal ID

# %%
list(mappings['CompanyToTickets'].items())[:2]
### key is the company id and value is a list of tickets ID, same company can have multiple tickets ID
# Out:
# [('9366128719', ['2227268264']),
#  ('9355871862',
#   ['1153128060',
#    '1184439975',
#    '1255495303',
#    '1258208860',
#    '1265785475',
#    '1271135644',
#    '1294735265',
#    '1296806165',
#    '1305598867',
#    '1317059345',
#    '1353741690',
#    '1377812063',
#    '1380677892',
#    '1428597842',
#    '1436802687',
#    '1444251475',
#    '1486045610',
#    '1486225212',
#    '1490751498',
#    '1501062400',
#    '1525208184',
#    '1526946139',
#    '1528572955',
#    '1531938692',
#    '1575993731',
#    '1578772008',
#    '1595350578',
#    '1597266872',
#    '1597391905',
#    '1601174888',
#    '1602159132',
#    '1606567201',
#    '1606585647',
#    '1606960707',
#    '1608271468',
#    '1608744106',
#    '1609058103',
#    '1609091896',
#    '1609096794',
#    '1609111093',
#    '1609765740',
#    '1609979182',
#    '1610373386',
#    '1610467704',
#    '1610471190',
#    '1610477343',
#    '1610876991',
#    '1611925122',
#    '1613205790',
#    '1615039154',
#    '1615155028',
#    '1615740539',
#    '1616085107',
#    '1616912930',
#    '1616927862',
#    '1617059116',
#    '1617281891',
#    '1617546321',
#    '1618968176',
#    '1619171169',
#    '1619986741',
#    '1625623139',
#    '1625625249',
#    '1626629758',
#    '1626650492',
#    '1627774831',
#    '1627805541',
#    '1628377493',
#    '1630918207',
#    '1632808454',
#    '1632851372',
#    '1632924441',
#    '1632986449',
#    '1634368170',
#    '1634435181',
#    '1634442307',
#    '1634446442',
#    '1634538657',
#    '1635527717',
#    '1637251607',
#    '1642016637',
#    '1647288748',
#    '1648491302',
#    '1654826917',
#    '1662715688',
#    '1663115797',
#    '1663234419',
#    '1663280946',
#    '1663356230',
#    '1663364661',
#    '1663365130',
#    '1663373682',
#    '1663399027',
#    '1663414812',
#    '1663414859',
#    '1663434329',
#    '1663638058',
#    '1663690556',
#    '1663858819',
#    '1667580428',
#    '1667869186',
#    '1667945814',
#    '1668080918',
#    '1668082098',
#    '1668307530',
#    '1669978409',
#    '1671291675',
#    '1671410243',
#    '1671598619',
#    '1671880254',
#    '1671927849',
#    '1672046132',
#    '1672207541',
#    '1672261468',
#    '1672329744',
#    '1673868563',
#    '1674104967',
#    '1675295823',
#    '1676690289',
#    '1679359389',
#    '1684485902',
#    '1687301231',
#    '1687878832',
#    '1693741097',
#    '1702764320',
#    '1705446995',
#    '1705759657',
#    '1705843580',
#    '1710386554',
#    '1710404247',
#    '1710764807',
#    '1713807959',
#    '1714314240',
#    '1715812500',
#    '1717051726',
#    '1717246300',
#    '1719544702',
#    '1720068900',
#    '1722077308',
#    '1722258460',
#    '1722540892',
#    '1724345369',
#    '1724821161',
#    '1724851749',
#    '1726989570',
#    '1728549497',
#    '1734631342',
#    '1740501852',
#    '1740584114',
#    '1744460128',
#    '1744471360',
#    '1751478016',
#    '1769031762',
#    '1772060287',
#    '1775676720',
#    '1777748825',
#    '1787365700',
#    '1788267125',
#    '1790290761',
#    '1800390244',
#    '1802503980',
#    '1838714012',
#    '1853819214',
#    '1854635671',
#    '1855101526',
#    '1855392290',
#    '1861962918',
#    '1867783432',
#    '1870575944',
#    '1874344236',
#    '1876784784',
#    '1879039829',
#    '1887888952',
#    '1896570765',
#    '1899231147',
#    '1899325604',
#    '1901895456',
#    '1905093475',
#    '1907151895',
#    '1907847046',
#    '1909771620',
#    '1915756380',
#    '1918362758',
#    '1923737469',
#    '1927282750',
#    '1927311196',
#    '1927362997',
#    '1927698019',
#    '1929107617',
#    '1930203000',
#    '1930641766',
#    '1930798343',
#    '1930821021',
#    '1931481147',
#    '1933145132',
#    '1933492054',
#    '1940054071',
#    '1941889671',
#    '1942102649',
#    '1942125886',
#    '1942717500',
#    '1944544420',
#    '1949034340',
#    '1951012627',
#    '1951033145',
#    '1952834361',
#    '1953117805',
#    '1953283162',
#    '1953349386',
#    '1954331905',
#    '1996850179',
#    '1996854331',
#    '1996958773',
#    '1997067377',
#    '1998023841',
#    '2002555010',
#    '2020354701',
#    '2035866512',
#    '2035974441',
#    '2035989609',
#    '2036204300',
#    '2036511277',
#    '2038302982',
#    '2042246478',
#    '2042724402',
#    '2043000686',
#    '2047561076',
#    '2053753948',
#    '2054857035',
#    '2066629201',
#    '2081931376',
#    '2083193474',
#    '2087591281',
#    '2088077977',
#    '2116225695',
#    '2120206440',
#    '2126784854',
#    '2158100752',
#    '2187995455',
#    '2191483241',
#    '2193328307',
#    '2193874050',
#    '2194490891',
#    '2198836607',
#    '2199533238',
#    '2241357902',
#    '2257012010',
#    '2260683277',
#    '2298459220',
#    '2324133650',
#    '2385753784',
#    '2394337569',
#    '2461057975',
#    '2464657255',
#    '2465879416',
#    '2474126507',
#    '2479320611',
#    '2485169431',
#    '2500564766',
#    '2500724299',
#    '2504809986',
#    '2506861903',
#    '2537322911',
#    '2537896618',
#    '2538001186',
#    '2542384267',
#    '2545601361',
#    '2550117020',
#    '2551026222',
#    '2551314289',
#    '2551560471',
#    '2553960748',
#    '2593041691',
#    '2599079582',
#    '2601398865',
#    '2622217331',
#    '2637137591',
#    '2644964946',
#    '2667613958',
#    '2781581195',
#    '2796111123',
#    '2806041407',
#    '2808721226',
#    '2847295903',
#    '2951801354',
#    '2953282710',
#    '2978474587',
#    '2985279035',
#    '2994689551',
#    '3045757293',
#    '3049105011',
#    '3049736857',
#    '3077833053',
#    '3091992415',
#    '3151224381',
#    '3162467096',
#    '3163829820',
#    '3183146752',
#    '3279985029',
#    '3479129371',
#    '3642551355',
#    '3903343507',
#    '4207952206',
#    '16746570295',
#    '19061237598',
#    '19437836971',
#    '20502082641',
#    '20506335613',
#    '20556709643'])]

# %% [markdown]
# ### Now, create a dictionary based on mappings['CompanyToTickets'] where the keys are ticket IDs and the values are company IDs. This will give us a one-to-one mapping between ticket IDs and company IDs, which we can later use to add a new company_id column to the ticket DataFrame.

# %%
# revert the company-ticket mapping
ticket_to_company = {}

for company_id, ticket_list in mappings["CompanyToTickets"].items():
    for ticket_id in ticket_list:
        ticket_to_company[ticket_id] = company_id

# %%
# ticket_to_company

# %%
### convert the ticket id column into string type
tickets['Ticket ID'] = tickets['Ticket ID'].astype(str)

# %%
### create a company ID column in the tickets dataset based on 'ticket_to_company' dictionary
tickets['Company ID'] = tickets['Ticket ID'].map(ticket_to_company)

# %%
### filter the company dataset and only keep columns with less than 90% missing values, you can also try your own threshold
companies = companies.loc[:, companies.isnull().mean() < 0.9]

# %%
### convert the integer type into string type for later mapping
companies['Record ID'] = companies['Record ID'].astype(str)

# %%
### you can merge the companys dataframe and the ticket dataframe
### here I did left merge, so only 79 rows are kept since tickets data only contains 79 rows
merged_tickets = pd.merge(left = tickets, right= companies, left_on= 'Company ID', right_on = 'Record ID', how = 'left')

# %% [markdown]
# ### You can follow a similar pattern to merge the tickets and deals datasets, or choose to merge only the companies and deals datasets, since the tickets dataset contains only 79 records.

# %% [markdown]
# # Data Cleaning and Processing on Ticket

# %%
tickets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 37 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Create date                                    79 non-null     object
#  1   Stage Date - Project Launch                    31 non-null     object
#  2   Associated Contact                             78 non-null     object
#  3   Target Launch Date                             29 non-null     object
#  4   Kickoff Call                                   49 non-null     object
#  5   Close date                                     55 non-null     object
#  6   Pipeline                                       79 non-null     object
#  7   Stage Date - Project Initiation                53 non-null     object
#  8   Ticket status                                  79 non-null     object
#  9   Stage Date - Execution                         37 non-null     object
#  10  Time to first agent email reply (HH:mm:ss)     56 non-null     object
#  11  Associated Company                             79 non-null     object
#  12  Stage Date - Closure Phase                     27 non-null     object
#  13  Associated Company (Primary)                   76 non-null     object
#  14  Response time (HH:mm:ss)                       56 non-null     object
#  15  Ticket ID                                      79 non-null     object
#  16  Time to close (HH:mm:ss)                       55 non-null     object
#  17  Associated Deal                                58 non-null     object
#  18  Library index approved                         43 non-null     object
#  19  Training: General Overview                     28 non-null     object
#  20  Latest Milestone                               20 non-null     object
#  21  Training: Deployment/User Management Training  26 non-null     object
#  22  Requirements for the Trial                     49 non-null     object
#  23  Training: Sym Building 101                     25 non-null     object
#  24  Last modified date                             79 non-null     object
#  25  Trial End Date                                 52 non-null     object
#  26  Training: Sym Building 201                     19 non-null     object
#  27  Stage Date - Converted Won                     30 non-null     object
#  28  Latest Milestone Update Date                   20 non-null     object
#  29  Ticket name                                    79 non-null     object
#  30  Trial Overview                                 65 non-null     object
#  31  Trial Start Date                               52 non-null     object
#  32  1st Syms presented for review                  21 non-null     object
#  33  Project Launch Day                             34 non-null     object
#  34  Training: Reporting                            24 non-null     object
#  35  Construction of 1st Sym begun                  43 non-null     object
#  36  Company ID                                     79 non-null     object
# dtypes: object(37)
# memory usage: 23.0+ KB

# %% [markdown]
# ## Missing Values

# %%
# Check and sort missing value ratios
missing_rate = tickets.isnull().mean().sort_values(ascending=False)
missing_rate[missing_rate > 0]  # Display only columns with missing values
# Out:
# Training: Sym Building 201                       0.759494
# Latest Milestone Update Date                     0.746835
# Latest Milestone                                 0.746835
# 1st Syms presented for review                    0.734177
# Training: Reporting                              0.696203
# Training: Sym Building 101                       0.683544
# Training: Deployment/User Management Training    0.670886
# Stage Date - Closure Phase                       0.658228
# Training: General Overview                       0.645570
# Target Launch Date                               0.632911
# Stage Date - Converted Won                       0.620253
# Stage Date - Project Launch                      0.607595
# Project Launch Day                               0.569620
# Stage Date - Execution                           0.531646
# Library index approved                           0.455696
# Construction of 1st Sym begun                    0.455696
# Requirements for the Trial                       0.379747
# Kickoff Call                                     0.379747
# Trial Start Date                                 0.341772
# Trial End Date                                   0.341772
# Stage Date - Project Initiation                  0.329114
# Time to close (HH:mm:ss)                         0.303797
# Close date                                       0.303797
# Time to first agent email reply (HH:mm:ss)       0.291139
# Response time (HH:mm:ss)                         0.291139
# Associated Deal                                  0.265823
# Trial Overview                                   0.177215
# Associated Company (Primary)                     0.037975
# Associated Contact                               0.012658
# dtype: float64

# %% [markdown]
# ## New Features

# %% [markdown]
# # EDA

# %%
tickets['Is Successful'] = (
    (tickets['Ticket status'] == 'Closed')
   # (tickets['1st syms run in production'].notnull())
)

# %%
tickets['Create date'] = pd.to_datetime(tickets['Create date'])
tickets['Close date'] = pd.to_datetime(tickets['Close date'])
tickets['Implementation_Duration_Days'] = (tickets['Close date'] - tickets['Create date']).dt.days

# %%
sns.histplot(data=tickets, x='Implementation_Duration_Days', hue='Is Successful', kde=True)
# Out:
# <Axes: xlabel='Implementation_Duration_Days', ylabel='Count'>

# %% [markdown]
# # Problems to solve in the Final Report and Posisble Solutions:

# %%
import pandas as pd

# Define the left column (objectives) and right column (model suggestions)
objectives = [
    "Segment prospective customers based on company characteristics and provide tailored outreach strategies",
    "Guide sales progression through pipeline stages with specific actions for each stage",
    "Predict deal outcomes based on company profile and deal characteristics",
    "Optimize implementation handoffs between sales and customer success",
    "Recommend resource allocation based on customer segment and complexity",
    "Present insights through an interactive dashboard for sales team usage",
    "Process data through an ETL pipeline to keep recommendations current",
    "Deploy as a containerized application for consistent environment setup"
]

model_suggestions = [
    "Clustering (KMeans, DBSCAN), EDA",
    'Look into the ticket data and the deals data, is all steps always needed for a successful deal? Is training always needed for upsell and new customers? ',
    "Classification models (Logistic Regression, Random Forest, XGBoost, Neural Network for Binary classification)",
    " ",
    "complexity can be measured by total tickets needed for each deal, average resolution time needed, etc, does different segments of customers have the same implementation complexity?  Does different segments of customers requires same actions?",
    "Streamlit",
    "ETL frameworks (Pandas pipelines), data cleaning scripts",
    "Docker, Docker Compose, Kubernetes for containerization and deployment"
]

# Create the dataframe
df = pd.DataFrame({
    "Project Objective": objectives,
    "Suggested Models / Tools": model_suggestions
})

# %%
df
# Out:
#                                    Project Objective  \
# 0  Segment prospective customers based on company...
# 1  Guide sales progression through pipeline stage...
# 2  Predict deal outcomes based on company profile...
# 3  Optimize implementation handoffs between sales...
# 4  Recommend resource allocation based on custome...
# 5  Present insights through an interactive dashbo...
# 6  Process data through an ETL pipeline to keep r...
# 7  Deploy as a containerized application for cons...
#
#                             Suggested Models / Tools
# 0                   Clustering (KMeans, DBSCAN), EDA
# 1  Look into the ticket data and the deals data, ...
# 2  Classification models (Logistic Regression, Ra...
# 3
# 4  complexity can be measured by total tickets ne...
# 5                                          Streamlit
# 6  ETL frameworks (Pandas pipelines), data cleani...
# 7  Docker, Docker Compose, Kubernetes for contain...

# %% [markdown]
# ### Possible Q&A
#
#
#
# ### Q1: What does it mean by ‘customer segment and complexity’ in the requirement *“Recommend resource allocation based on customer segment and complexity”*? Also, what are the actions to take at each stage — aren’t those actions fixed?
#
# **A1:**
# Customer segment and implementation complexity can be evaluated primarily through the **ticket data**. Some useful indicators include:
#
# - Number of support tickets generated per implementation (more tickets may indicate higher complexity)
# - Average resolution time for implementation-related issues
# - Whether SSO (Single Sign-On) was required and whether it accelerated or delayed implementation
#
# You can quantify **implementation complexity** by engineering a feature that aggregates these signals.
#
#
# ### Q2: What are the actions to take at each stage — aren’t those actions fixed?
#
# **A:**
# Yes, the standard actions for each stage are typically fixed. However, the ticket and deal data may reveal valuable insights that can help **adapt or skip certain stages** under specific conditions. For example:
#
# - If the deal is an **upsell** to an existing customer, the **training stage** may not be necessary, as the customer is already familiar with the product.
# - What does historical data show? Have some successful deals **skipped onboarding or negotiation** and still closed faster or more successfully?

# %% [markdown]
# # Final Report Format
#
# 1. Title Page (project title, course name, group member name and VUID)
# 2. Introduction
# 3. Data Overview & Exploration
# 4. Data Processing
# 5. Model Deployment
# 6. Dashboard & Visualization
# 7. Deployment & Technical Implementation
# 8. Business Insights & Recommendations
# 9. Conclusion & Future Work
# 10. References (if applicable)
